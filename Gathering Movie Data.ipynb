# %% [markdown]
# # Gathering Movie Data
#
# ### Method: Wikipedia API
# It appears that Wikipedia would be a good source to scrape information from.
# Wikipedia permits scraping for non-commerical "Creative Commons Share-Alike" ventures: see https://en.wikipedia.org/wiki/Wikipedia:Reusing_Wikipedia_content and their public API: https://pypi.org/project/wikipedia/

# %%
# you must install the following: 
# pip install wikipedia
# pip install wikipedia_sections
import wikipedia

# %% [markdown]
# ### api exploration

# %%
films_1940 = wikipedia.page("1940 in film")
films_1940.content[:100]
# Out:
# 'The year 1940 in film involved some significant events, including the premieres of the Walt Disney f'

# %%
films_1940.sections # warning: this will be blank if you did not install wikipedia-sections

# %%
films_1940.section('A')

# %%
films_1940.section('Z')

# %% [markdown]
# ### Movie Title Dataset Creation

# %%
# this method of scraping only works until 1972
years = range(1940, 1973, 1) 
title = lambda y : f"{y} in film"
Alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %%
title_dict = {}

for year in years: 
    page = wikipedia.page(title(year))    
    list_movies = []
    for C in Alphabet: 
        text = page.section(C)
        
        if text is not None: 
            section_movies = text.split('\n')
            section_movies = [line.split(',')[0] for line in section_movies]
            list_movies += section_movies
            
    title_dict[year] = list_movies

# %%
years = range(1974, 2024, 1)

# %%
import IPython.display as display

current = 0
total = len(years)
for year in years: 
    print(year)
    title_dict[year] = []
    
    # display progress
    current += 1
    display.clear_output(wait=True)
    progress = '{0:.2f}'.format(current*100/total)
    display.display(f"Progress: {progress}%")

    dfs = []
    try:
        html = requests.get(f"https://en.wikipedia.org/wiki/List_of_American_films_of_{year}").text
        dfs = pd.read_html(html)
    except Exception as e: 
        print(e)
        continue 
    
    for df in dfs:
        if('Title' in df.columns):
            title_dict[year] += list(df['Title'])
# Out:
# 'Progress: 100.00%'
# C:\Users\mumle\AppData\Local\Temp\ipykernel_12780\3105982912.py:18: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html)

# %%
title_dict
# Out:
# {1940: ['Abe Lincoln in Illinois',
#   'All This and Heaven Too',
#   'Andy Hardy Meets Debutante',
#   'Angels Over Broadway',
#   'Anne of Windy Poplars',
#   'The Ape',
#   'Arise',
#   'Arizona',
#   'Band Waggon',
#   'The Bank Dick',
#   'Beating Heart',
#   'Before I Hang',
#   'The Biscuit Eater',
#   'Bismarck',
#   'Black Friday',
#   'The Blue Bird',
#   'Boom Town',
#   'The Boys from Syracuse',
#   'Boys of the City',
#   'Brigham Young',
#   'British Intelligence',
#   'Broadway Melody of 1940',
#   'Brother Orchid',
#   'Calling Philo Vance',
#   'Castle on the Hudson',
#   'The Catacombs (Katakomby)',
#   'Charlie Chan at the Wax Museum',
#   'Charlie Chan in Panama',
#   'Christmas in July',
#   'A Chump at Oxford',
#   'City for Conquest',
#   'Confucius – (China)',
#   'Contraband',
#   'Convicted Woman',
#   'Convoy – directed by Pen Tennyson',
#   'Crimes at the Dark House',
#   'Dance',
#   'Dark Command',
#   "Dead Man's Shoes",
#   'The Devil Bat',
#   "A Dispatch from Reuter's",
#   'Dívka v modrém – (Czechoslovakia)',
#   'Doomed to Die',
#   'Down Argentine Way',
#   'Dr. Cyclops',
#   "Dr. Ehrlich's Magic Bullet",
#   'East Side Kids',
#   'Edison',
#   'Ergens in Nederland (Somewhere in the Netherlands) – (Netherlands)',
#   'Escape',
#   'Fantasia',
#   'The Fatal Hour',
#   'Flowing Gold',
#   'Foreign Correspondent',
#   'Four Sons',
#   'The Fox of Glenarvon',
#   'French Without Tears',
#   'Gaslight',
#   'The Ghost Breakers',
#   'Girl in the News',
#   'Give Us Wings',
#   'Go West',
#   'The Grapes of Wrath',
#   'The Great Dictator',
#   'The Great McGinty',
#   'Green Hell',
#   'Here Is the Point (Ahí está el detalle)',
#   'His Girl Friday',
#   'Hoots Mon!',
#   'The House Across the Bay',
#   'The House of the Seven Gables',
#   'The Howards of Virginia',
#   'Hullabaloo',
#   'I Love You Again',
#   'I Take This Woman',
#   'The Invisible Man Returns',
#   'The Invisible Woman',
#   'It All Came True',
#   'June Nights (Juninatten)',
#   'King of the White Elephant (Prajao Changpeuk) – (Thailand)',
#   'Kitty Foyle',
#   'Laddie',
#   'Lady with Red Hair',
#   'The Letter',
#   'Lillian Russell',
#   'Little Men',
#   'The Long Voyage Home',
#   'Maddalena',
#   'The Man from Dakota',
#   'The Man Who Talked Too Much',
#   'The Marines Fly High',
#   'The Mark of Zorro',
#   'The Middle Watch',
#   "The Minister's Girlfriends (Přítelkyně pana ministra) – (Czechoslovakia)",
#   'Millionaires in Prison',
#   'The Mortal Storm',
#   "The Mummy's Hand",
#   'My Favorite Wife',
#   'My Little Chickadee',
#   'New Moon',
#   'Night Train to Munich',
#   'North West Mounted Police',
#   'Northwest Passage',
#   'One Million B.C. (aka The Cave Dwellers)',
#   'One Night in the Tropics',
#   'Our Town',
#   'Pastor Hall',
#   'The Philadelphia Story',
#   'Pinocchio',
#   'Pride and Prejudice',
#   'Primrose Path',
#   'The Proud Valley',
#   'Queen Elizabeth',
#   'Queen of the Yukon',
#   'Rebecca',
#   'Remember the Night',
#   'Rhythm on the River',
#   'Road to Singapore',
#   'Saps at Sea',
#   'The Sea Hawk',
#   'Seven Sinners',
#   'The Shop Around the Corner',
#   "The Siege of the Alcazar (L'Assedio dell'Alcazar) – (Italy)",
#   'Sky Murder',
#   'Son of Ingagi',
#   'The Son of Monte Cristo',
#   'Spring Parade',
#   'The Stars Look Down',
#   'The Stationmaster (Der postmeister) – (Germany)',
#   'Strange Cargo',
#   'Stranger on the Third Floor',
#   'Strike Up the Band',
#   'South of Suez',
#   'Swiss Family Robinson',
#   'They Drive by Night',
#   'They Knew What They Wanted',
#   'The Thief of Bagdad',
#   "'Til We Meet Again",
#   "Tom Brown's School Days",
#   'Too Many Girls',
#   'Too Many Husbands',
#   'Tørres Snørtevold – (Norway)',
#   'Torrid Zone',
#   'Turnabout',
#   'Vigil in the Night',
#   'Virginia City',
#   'Waterloo Bridge',
#   "The Well-Digger's Daughter (La Fille du puisatier)",
#   'The Westerner',
#   "Where's That Fire?",
#   'Wild Horse Range',
#   'Women in War',
#   'Young People',
#   'Young Tom Edison',
#   "You're Not So Tough"],
#  1941: ['Abe Lincoln in Illinois',
#   'All This and Heaven Too',
#   'Andy Hardy Meets Debutante',
#   'Angels Over Broadway',
#   'Anne of Windy Poplars',
#   'The Ape',
#   'Arise',
#   'Arizona',
#   'Band Waggon',
#   'The Bank Dick',
#   'Beating Heart',
#   'Before I Hang',
#   'The Biscuit Eater',
#   'Bismarck',
#   'Black Friday',
#   'The Blue Bird',
#   'Boom Town',
#   'The Boys from Syracuse',
#   'Boys of the City',
#   'Brigham Young',
#   'British Intelligence',
#   'Broadway Melody of 1940',
#   'Brother Orchid',
#   'Calling Philo Vance',
#   'Castle on the Hudson',
#   'The Catacombs (Katakomby)',
#   'Charlie Chan at the Wax Museum',
#   'Charlie Chan in Panama',
#   'Christmas in July',
#   'A Chump at Oxford',
#   'City for Conquest',
#   'Confucius – (China)',
#   'Contraband',
#   'Convicted Woman',
#   'Convoy – directed by Pen Tennyson',
#   'Crimes at the Dark House',
#   'Dance',
#   'Dark Command',
#   "Dead Man's Shoes",
#   'The Devil Bat',
#   "A Dispatch from Reuter's",
#   'Dívka v modrém – (Czechoslovakia)',
#   'Doomed to Die',
#   'Down Argentine Way',
#   'Dr. Cyclops',
#   "Dr. Ehrlich's Magic Bullet",
#   'East Side Kids',
#   'Edison',
#   'Ergens in Nederland (Somewhere in the Netherlands) – (Netherlands)',
#   'Escape',
#   'Fantasia',
#   'The Fatal Hour',
#   'Flowing Gold',
#   'Foreign Correspondent',
#   'Four Sons',
#   'The Fox of Glenarvon',
#   'French Without Tears',
#   'Gaslight',
#   'The Ghost Breakers',
#   'Girl in the News',
#   'Give Us Wings',
#   'Go West',
#   'The Grapes of Wrath',
#   'The Great Dictator',
#   'The Great McGinty',
#   'Green Hell',
#   'Here Is the Point (Ahí está el detalle)',
#   'His Girl Friday',
#   'Hoots Mon!',
#   'The House Across the Bay',
#   'The House of the Seven Gables',
#   'The Howards of Virginia',
#   'Hullabaloo',
#   'I Love You Again',
#   'I Take This Woman',
#   'The Invisible Man Returns',
#   'The Invisible Woman',
#   'It All Came True',
#   'June Nights (Juninatten)',
#   'King of the White Elephant (Prajao Changpeuk) – (Thailand)',
#   'Kitty Foyle',
#   'Laddie',
#   'Lady with Red Hair',
#   'The Letter',
#   'Lillian Russell',
#   'Little Men',
#   'The Long Voyage Home',
#   'Maddalena',
#   'The Man from Dakota',
#   'The Man Who Talked Too Much',
#   'The Marines Fly High',
#   'The Mark of Zorro',
#   'The Middle Watch',
#   "The Minister's Girlfriends (Přítelkyně pana ministra) – (Czechoslovakia)",
#   'Millionaires in Prison',
#   'The Mortal Storm',
#   "The Mummy's Hand",
#   'My Favorite Wife',
#   'My Little Chickadee',
#   'New Moon',
#   'Night Train to Munich',
#   'North West Mounted Police',
#   'Northwest Passage',
#   'One Million B.C. (aka The Cave Dwellers)',
#   'One Night in the Tropics',
#   'Our Town',
#   'Pastor Hall',
#   'The Philadelphia Story',
#   'Pinocchio',
#   'Pride and Prejudice',
#   'Primrose Path',
#   'The Proud Valley',
#   'Queen Elizabeth',
#   'Queen of the Yukon',
#   'Rebecca',
#   'Remember the Night',
#   'Rhythm on the River',
#   'Road to Singapore',
#   'Saps at Sea',
#   'The Sea Hawk',
#   'Seven Sinners',
#   'The Shop Around the Corner',
#   "The Siege of the Alcazar (L'Assedio dell'Alcazar) – (Italy)",
#   'Sky Murder',
#   'Son of Ingagi',
#   'The Son of Monte Cristo',
#   'Spring Parade',
#   'The Stars Look Down',
#   'The Stationmaster (Der postmeister) – (Germany)',
#   'Strange Cargo',
#   'Stranger on the Third Floor',
#   'Strike Up the Band',
#   'South of Suez',
#   'Swiss Family Robinson',
#   'They Drive by Night',
#   'They Knew What They Wanted',
#   'The Thief of Bagdad',
#   "'Til We Meet Again",
#   "Tom Brown's School Days",
#   'Too Many Girls',
#   'Too Many Husbands',
#   'Tørres Snørtevold – (Norway)',
#   'Torrid Zone',
#   'Turnabout',
#   'Vigil in the Night',
#   'Virginia City',
#   'Waterloo Bridge',
#   "The Well-Digger's Daughter (La Fille du puisatier)",
#   'The Westerner',
#   "Where's That Fire?",
#   'Wild Horse Range',
#   'Women in War',
#   'Young People',
#   'Young Tom Edison',
#   "You're Not So Tough"],
#  1942: ['Aar Paar (This or That)',
#   'About Mrs. Leslie',
#   'Robinson Crusoe (Aventuras de Robinson Crusoe)',
#   'Alaska Seas',
#   'Amar (Immortal)',
#   'An American in Rome (Un americano a Roma)',
#   'Andha Naal (That Day) – (India)',
#   'Animal Farm',
#   'Apache',
#   'Attila',
#   'Bahut Din Huwe',
#   'The Back of Beyond – (Australia)',
#   'The Barefoot Contessa',
#   'Beachhead',
#   'Beau Brummell',
#   'Beautiful Stranger',
#   "The Belles of St. Trinian's",
#   'Betrayed',
#   'A Big Family (Bolshaya semya) – (USSR)',
#   'The Black Knight',
#   'The Black Shield of Falworth',
#   'Black Tuesday',
#   'Black Widow',
#   'Boot Polish – (India)',
#   'Boris Godunov – (USSR)',
#   'The Bowery Boys Meet the Monsters',
#   'Bread',
#   'The Bridges at Toko-Ri',
#   'Brigadoon',
#   'Broken Lance',
#   'Cadet Rousselle',
#   'The Caine Mutiny',
#   'Canaris',
#   'Carmen Jones',
#   "Casanova's Big Night",
#   'Chronicle of Poor Lovers (Cronache di poveri amanti) – (Italy)',
#   'Circus Fandango – (Norway)',
#   'The Country Girl',
#   'Creature from the Black Lagoon',
#   'Crime Wave',
#   'Crossed Swords ([Il Maestro di Don Giovanni])',
#   'The Crucified Lovers (Chikamatsu Monogatari)',
#   'Dangerous Mission',
#   'Deep in My Heart',
#   'Demetrius and the Gladiators',
#   'Désirée',
#   'Dial M for Murder',
#   'Doctor in the House',
#   'Down Three Dark Streets',
#   'Drive a Crooked Road',
#   'Drum Beat',
#   'The Egyptian',
#   "Eight O'Clock Walk",
#   'Elephant Walk',
#   'Executive Suite',
#   'The Far Country',
#   'Father Brown',
#   'Fear (La Paura)',
#   'Five Boys from Barska Street (Piątka z ulicy Barskiej) – (Poland)',
#   'Flame and the Flesh',
#   'French Cancan',
#   'The French Line',
#   'Garden of Evil',
#   'The Glenn Miller Story',
#   'Godzilla (Gojira)',
#   "The Gold of Naples (L'oro di Napoli)",
#   'The Good Die Young',
#   'Hansel and Gretel: An Opera Fantasy',
#   'Happy Ever After',
#   'Hell and High Water',
#   'Hell Below Zero',
#   "Hell's Half Acre",
#   'The High and the Mighty',
#   'Highway Dragnet',
#   "Hobson's Choice",
#   'The House Across the Lake',
#   'Human Desire',
#   'Illusion Travels by Streetcar (La ilusión viaja en tranvía)',
#   'Inauguration of the Pleasure Dome',
#   'An Inspector Calls',
#   'It Should Happen to You',
#   'Jagriti (The Awakening) – (India)',
#   'Johnny Guitar',
#   'Journey to Italy (Viaggio in Italia)',
#   'King Richard and the Crusaders',
#   'Knock on Wood',
#   'The Lady of the Camellias (La Mujer de las camelias) – (Argentina)',
#   'The Last Bridge (Die Letzte Brücke)',
#   'Late Chrysanthemums (bangiku)',
#   'A Lesson in Love (En lektion i kärlek)',
#   'A Life at Stake',
#   'Liliomfi – (Hungary)',
#   'Living It Up',
#   'The Long',
#   'The Long Wait',
#   'Loophole',
#   'Mad About Men',
#   'Madame X (I Agnostos)Madame X (1954 film) – (Greece)',
#   'Maddalena – (Italy)',
#   'The Maggie',
#   'Magnificent Obsession',
#   'The Million Pound Note',
#   'Nagin',
#   'Naked Alibi',
#   'The Naked Jungle',
#   'Neelakuyil (The Blue Cuckoo) – (India)',
#   'Night People',
#   'Nothing But Trouble (Aldri annet enn bråk) – (Norway)',
#   'On the Waterfront',
#   "On Trial (L'affaire Maurizius; Il caso Mauritius)",
#   'The Outcast',
#   'Phantom of the Rue Morgue',
#   'Phffft',
#   'Pride of the Blue Grass',
#   'Prince Valiant',
#   'Prisoner of War',
#   'Private Hell 36',
#   'Pushover',
#   'Radio Cab Murder',
#   'The Raid',
#   'Rear Window',
#   'Red Garters',
#   'Return to Treasure Island',
#   'Riot in Cell Block 11',
#   'River of No Return',
#   'Robinson Crusoe',
#   'Rogue Cop',
#   'Romeo and Juliet',
#   'Sabrina',
#   'Salt of the Earth',
#   'Samurai I: Musashi Miyamoto (Miyamoto Musashi)',
#   'Sansho the Bailiff (Sanshō Dayũ)',
#   'Saskatchewan',
#   'The Sea Shall Not Have Them',
#   'Secret of the Incas',
#   'The Seekers',
#   'Senso',
#   'Seven Brides for Seven Brothers',
#   'Seven Samurai (Shichinin no Samurai)',
#   "She Couldn't Say No",
#   'Shield for Murder',
#   'The Silver Chalice',
#   'Silver Lode',
#   'Sira` Fi al-Wadi (Struggle in the Valley)',
#   'Sitting Bull',
#   'Sound of the Mountain (Yama no Oto)',
#   'A Star Is Born',
#   'Star of India',
#   'La strada (The Road)',
#   'Stranger from Venus',
#   'Suddenly',
#   'Supir Istimewa',
#   'Susan Slept Here',
#   'Tanganyika',
#   'Taza',
#   'Them!',
#   "There's No Business Like Show Business",
#   'They Who Dare',
#   'Three Coins in the Fountain',
#   'Three Young Texans',
#   "Too Bad She's Bad (Peccato che sia una canaglia)",
#   'Top Banana',
#   'Touchez pas au grisbi (Hands Off the Loot)',
#   'Track of the Cat',
#   'Twenty-Four Eyes (Nijū-shi no Hitomi) – (Japan)',
#   'Twist of Fate',
#   'Vera Cruz',
#   'The Weak and the Wicked',
#   'West of Zanzibar (1954 film)',
#   'White Christmas',
#   'Windfall in Athens (Kyriakatiko xypnima)',
#   'Witness to Murder',
#   "Woman's World",
#   'Wyoming Renegades',
#   'Young at Heart',
#   'The Young Lovers'],
#  1943: ['Abe Lincoln in Illinois',
#   'All This and Heaven Too',
#   'Andy Hardy Meets Debutante',
#   'Angels Over Broadway',
#   'Anne of Windy Poplars',
#   'The Ape',
#   'Arise',
#   'Arizona',
#   'Band Waggon',
#   'The Bank Dick',
#   'Beating Heart',
#   'Before I Hang',
#   'The Biscuit Eater',
#   'Bismarck',
#   'Black Friday',
#   'The Blue Bird',
#   'Boom Town',
#   'The Boys from Syracuse',
#   'Boys of the City',
#   'Brigham Young',
#   'British Intelligence',
#   'Broadway Melody of 1940',
#   'Brother Orchid',
#   'Calling Philo Vance',
#   'Castle on the Hudson',
#   'The Catacombs (Katakomby)',
#   'Charlie Chan at the Wax Museum',
#   'Charlie Chan in Panama',
#   'Christmas in July',
#   'A Chump at Oxford',
#   'City for Conquest',
#   'Confucius – (China)',
#   'Contraband',
#   'Convicted Woman',
#   'Convoy – directed by Pen Tennyson',
#   'Crimes at the Dark House',
#   'Dance',
#   'Dark Command',
#   "Dead Man's Shoes",
#   'The Devil Bat',
#   "A Dispatch from Reuter's",
#   'Dívka v modrém – (Czechoslovakia)',
#   'Doomed to Die',
#   'Down Argentine Way',
#   'Dr. Cyclops',
#   "Dr. Ehrlich's Magic Bullet",
#   'East Side Kids',
#   'Edison',
#   'Ergens in Nederland (Somewhere in the Netherlands) – (Netherlands)',
#   'Escape',
#   'Fantasia',
#   'The Fatal Hour',
#   'Flowing Gold',
#   'Foreign Correspondent',
#   'Four Sons',
#   'The Fox of Glenarvon',
#   'French Without Tears',
#   'Gaslight',
#   'The Ghost Breakers',
#   'Girl in the News',
#   'Give Us Wings',
#   'Go West',
#   'The Grapes of Wrath',
#   'The Great Dictator',
#   'The Great McGinty',
#   'Green Hell',
#   'Here Is the Point (Ahí está el detalle)',
#   'His Girl Friday',
#   'Hoots Mon!',
#   'The House Across the Bay',
#   'The House of the Seven Gables',
#   'The Howards of Virginia',
#   'Hullabaloo',
#   'I Love You Again',
#   'I Take This Woman',
#   'The Invisible Man Returns',
#   'The Invisible Woman',
#   'It All Came True',
#   'June Nights (Juninatten)',
#   'King of the White Elephant (Prajao Changpeuk) – (Thailand)',
#   'Kitty Foyle',
#   'Laddie',
#   'Lady with Red Hair',
#   'The Letter',
#   'Lillian Russell',
#   'Little Men',
#   'The Long Voyage Home',
#   'Maddalena',
#   'The Man from Dakota',
#   'The Man Who Talked Too Much',
#   'The Marines Fly High',
#   'The Mark of Zorro',
#   'The Middle Watch',
#   "The Minister's Girlfriends (Přítelkyně pana ministra) – (Czechoslovakia)",
#   'Millionaires in Prison',
#   'The Mortal Storm',
#   "The Mummy's Hand",
#   'My Favorite Wife',
#   'My Little Chickadee',
#   'New Moon',
#   'Night Train to Munich',
#   'North West Mounted Police',
#   'Northwest Passage',
#   'One Million B.C. (aka The Cave Dwellers)',
#   'One Night in the Tropics',
#   'Our Town',
#   'Pastor Hall',
#   'The Philadelphia Story',
#   'Pinocchio',
#   'Pride and Prejudice',
#   'Primrose Path',
#   'The Proud Valley',
#   'Queen Elizabeth',
#   'Queen of the Yukon',
#   'Rebecca',
#   'Remember the Night',
#   'Rhythm on the River',
#   'Road to Singapore',
#   'Saps at Sea',
#   'The Sea Hawk',
#   'Seven Sinners',
#   'The Shop Around the Corner',
#   "The Siege of the Alcazar (L'Assedio dell'Alcazar) – (Italy)",
#   'Sky Murder',
#   'Son of Ingagi',
#   'The Son of Monte Cristo',
#   'Spring Parade',
#   'The Stars Look Down',
#   'The Stationmaster (Der postmeister) – (Germany)',
#   'Strange Cargo',
#   'Stranger on the Third Floor',
#   'Strike Up the Band',
#   'South of Suez',
#   'Swiss Family Robinson',
#   'They Drive by Night',
#   'They Knew What They Wanted',
#   'The Thief of Bagdad',
#   "'Til We Meet Again",
#   "Tom Brown's School Days",
#   'Too Many Girls',
#   'Too Many Husbands',
#   'Tørres Snørtevold – (Norway)',
#   'Torrid Zone',
#   'Turnabout',
#   'Vigil in the Night',
#   'Virginia City',
#   'Waterloo Bridge',
#   "The Well-Digger's Daughter (La Fille du puisatier)",
#   'The Westerner',
#   "Where's That Fire?",
#   'Wild Horse Range',
#   'Women in War',
#   'Young People',
#   'Young Tom Edison',
#   "You're Not So Tough"],
#  1944: ['The Adventures of Mark Twain',
#   'Ali Baba and the Forty Thieves',
#   'And Now Tomorrow',
#   'And the Angels Sing',
#   'Army (陸軍',
#   'Arsenic and Old Lace',
#   'At Land',
#   'Bathing Beauty',
#   'Berlanti',
#   'Between Two Worlds',
#   'The Black Pirate (El corsario negro)',
#   'The Bridge of San Luis Rey',
#   'Buffalo Bill',
#   'A Bullet in the Heart (Rossassa Fel Qalb) – (Egypt)',
#   'Candlelight in Algeria',
#   "Can't Help Singing",
#   'A Canterbury Tale',
#   'The Canterville Ghost',
#   'Casanova Brown',
#   'Champagne Charlie',
#   'The Children Are Watching Us (I bambini ci guardano)',
#   'Christmas Holiday',
#   'The Climax',
#   'Cobra Woman',
#   'The Conspirators',
#   'Cover Girl',
#   'Cowboy and the Senorita',
#   'Crime by Night',
#   'Cry of the Werewolf',
#   'The Curse of the Cat People',
#   'Days of Glory',
#   "Don't Take It to Heart",
#   'Double Indemnity',
#   'Dragon Seed',
#   'Dream of the Red Chamber (Hong lou meng) – (China)',
#   'Enemy of Women',
#   'Experiment Perilous',
#   'Fanny by Gaslight',
#   'Fiddlers Three',
#   'The Fighting Seabees',
#   'The Fighting Sullivans',
#   'For Those in Peril',
#   "Frenchman's Creek",
#   'Die Feuerzangenbowle (The Punch Bowl) – (Germany)',
#   'Gaslight',
#   'Going My Way',
#   'The Great Moment',
#   'Greenwich Village',
#   'The Great Sacrifice (Opfergang) – (Germany)',
#   'Hail the Conquering Hero',
#   'The Halfway House',
#   'The Heavenly Body',
#   'Henry V',
#   'The Hitler Gang',
#   'Hollywood Canteen',
#   'Home in Indiana',
#   'The Hour Before the Dawn',
#   'House of Frankenstein',
#   "I'll Be Seeing You",
#   'In Our Time',
#   'In Society',
#   'It Happened Tomorrow',
#   'Ivan the Terrible (Ivan Grozniy)',
#   'Janie',
#   'Jwar Bhata – (India)',
#   'The Keys of the Kingdom',
#   'Knickerbocker Holiday',
#   'Kismet',
#   'Lady in the Dark',
#   'Lady',
#   'Lake Placid Serenade',
#   'Laura',
#   'Lifeboat',
#   'The Lodger',
#   'Lost in a Harem',
#   'Man from Frisco directed by Robert Florey',
#   'Marie-Louise directed by Leopold Lindtberg and an uncredited Franz Schnyder',
#   'The Mask of Dimitrios',
#   'Meet Me in St. Louis',
#   'Meet the People',
#   'Melody of Murder (Mordets Melodi) – (Denmark)',
#   'Memphis Belle: A Story of a Flying Fortress',
#   'Ministry of Fear',
#   "The Miracle of Morgan's Creek",
#   'Mr. Skeffington',
#   'Mrs. Parkington',
#   "The Mummy's Curse",
#   "The Mummy's Ghost",
#   'Murder',
#   'Music for Millions',
#   'The Nail (El clavo) – (Spain)',
#   'National Velvet',
#   'None but the Lonely Heart',
#   'None Shall Escape',
#   'On Approval',
#   'Once Upon a Time',
#   'Our Hearts Were Young and Gay',
#   'Pardon My Rhythm',
#   'Passage to Marseille',
#   'The Pearl of Death',
#   'Phantom Lady',
#   'Pin Up Girl',
#   'Port of Freedom (Große Freiheit Nr. 7) – (Germany)',
#   'Possession (Besættelse) – (Denmark)',
#   'The Princess and the Pirate',
#   'The Purple Heart',
#   'Rainbow (Raduga) – (U.S.S.R.)',
#   'Rationing',
#   'The Rats of Tobruk (aka The Fighting Rats of Tobruk)',
#   'The Respectable Ladies of Pardubice (Počestné paní pardubické)',
#   'The Scarlet Claw',
#   'The Seventh Cross',
#   'Sherlock Holmes and The Spider Woman',
#   'Since You Went Away',
#   'Something for the Boys starring Carmen Miranda',
#   'Song of Russia',
#   'The Soul of a Monster',
#   'Storm Over Lisbon',
#   'The Story of Dr. Wassell',
#   'Sunday Dinner for a Soldier',
#   'The Suspect',
#   'Tall in the Saddle',
#   'Thirty Seconds over Tokyo',
#   'This Happy Breed',
#   'The Three Caballeros',
#   'Time Flies',
#   'To Have And Have Not',
#   'Torment (Hets)',
#   'The Tower of the Seven Hunchbacks (La Torre de los Siete Jorobados) – (Spain)',
#   'Tunisian Victory',
#   'Two Thousand Women',
#   'The Uninvited',
#   'Up in Arms',
#   'The Way Ahead (Immortal Battalion)',
#   'Weird Woman',
#   'When Strangers Marry',
#   'The White Cliffs of Dover',
#   'Wilson',
#   'Wing and a Prayer',
#   'The Woman in the Window',
#   'The Yellow Rose of Texas'],
#  1945: ['The Abandoned (Las Abandonadas)',
#   'Abbott and Costello in Hollywood',
#   'Allotment Wives',
#   'Along Came Jones',
#   'Amok – (Mexico)',
#   'Anchors Aweigh',
#   'And Then There Were None',
#   'Back to Bataan',
#   'A Bell For Adano',
#   "The Bells of St. Mary's",
#   'Blithe Spirit',
#   'Blood on the Sun',
#   'The Body Snatcher',
#   'Boule de suif (Angel and Sinner) – (France)',
#   'Bougainvillea (Bugambilia)',
#   "Brewster's Millions",
#   'Brief Encounter',
#   'Caesar and Cleopatra',
#   'Captain Kidd',
#   'The Cheaters',
#   'The Cherokee Flash',
#   'Children of Paradise (Les Enfants du Paradis)',
#   'Christmas in Connecticut',
#   'Circus Cavalcade (La cabalgata del circo) – (Argentina)',
#   'The Clock',
#   'Confidential Agent',
#   'Conflict',
#   'Counter-Attack',
#   'The Corn Is Green',
#   'Cornered',
#   'Dakota',
#   'Les dames du Bois de Boulogne',
#   'Dead of Night',
#   'Death Mills',
#   'Detour',
#   'Diamond Horseshoe',
#   'Dick Tracy',
#   'Dillinger',
#   'The Dolly Sisters',
#   'The Enchanted Cottage',
#   'The Enchanted Forest',
#   'Escape in the Fog',
#   'Fallen Angel',
#   'Flame of Barbary Coast',
#   'The Great Flamarion',
#   'Guest Wife',
#   'Gun Smoke',
#   'Hangover Square',
#   'Here Come the Co-Eds',
#   'High Powered',
#   'The Horn Blows at Midnight',
#   'Hotel Berlin',
#   'The House I Live In',
#   'House of Dracula',
#   'The House of Fear (1945 film)',
#   'The House on 92nd Street',
#   'Humayun',
#   "I Know Where I'm Going!",
#   'I Live in Grosvenor Square',
#   "I'll Be Your Sweetheart",
#   'Incendiary Blonde',
#   'The Invisible Army (Den usynlige hær) – (Denmark)',
#   'Isle of the Dead',
#   "It's in the Bag!",
#   'Johnny Angel',
#   'Kiss and Tell',
#   'Kitty',
#   'Kolberg – (Nazi Germany)',
#   'Lady on a Train',
#   'The Last Chance (Die letzte Chance) – (Switzerland)',
#   'Leave Her to Heaven',
#   'Life Begins Anew',
#   'The Lost Letter (Propavshaya gramota) – (USSR)',
#   'The Lost Weekend',
#   'Love Letters',
#   'Madonna of the Seven Moons',
#   'The Man in Half Moon Street',
#   'A Medal for Benny',
#   "The Men who Tread on the Tiger's Tail (Tora no o wo fumu otokotachi)",
#   'Mildred Pierce',
#   'Mom and Dad',
#   'Momotaro',
#   'My Name is Julia Ross',
#   'The Naughty Nineties',
#   'Objective',
#   'Our Vines Have Tender Grapes',
#   'Pardon My Past',
#   'Perfect Strangers',
#   'The Picture of Dorian Gray',
#   'Pink String and Sealing Wax',
#   'La porta del cielo (The Gate of Heaven)',
#   'Pride of the Marines',
#   'Pursuit to Algiers',
#   "The Rake's Progress",
#   'The Red Meadows (De røde enge) – (Denmark)',
#   'Rhapsody in Blue',
#   "Rockin' in the Rockies",
#   'Roll Call in Heaven (Cuando en el cielo pasen lista) – (Argentina)',
#   'Rome',
#   'A Royal Scandal',
#   "Rustlers' Hideout",
#   'Salome Where She Danced',
#   'San Antonio',
#   'Saratoga Trunk',
#   'Scarlet Street',
#   'La selva de fuego (The Forest Fire)',
#   'The Seventh Veil',
#   'Son of Lassie',
#   'A Song to Remember',
#   'The Southerner',
#   'The Spanish Main',
#   'Spellbound',
#   'State Fair',
#   'The Stork Club',
#   'The Story of G.I. Joe',
#   'The Strange Affair of Uncle Harry',
#   "That's the Spirit",
#   'They Were Expendable',
#   'The Thin Man Goes Home',
#   "This Man's Navy",
#   'The Three Caballeros',
#   'Thrill of a Romance',
#   'Thunderhead',
#   'Tonight and Every Night',
#   'A Tree Grows In Brooklyn',
#   'Twice Blessed',
#   "Two O'Clock Courage",
#   'The Unseen',
#   'The Valley of Decision',
#   'La vida en un hilo (Life on a Wire) – (Spain)',
#   'A Walk in the Sun',
#   'War Comes to America',
#   'Waterloo Road',
#   'The Way to the Stars',
#   'The Wicked Lady',
#   'Without Love',
#   'The Woman in Green',
#   'Wonder Man',
#   'Yolanda and the Thief',
#   'Ziegfeld Follies'],
#  1946: ['Accused of Murder',
#   'Alexander the Great',
#   'Ali Baba and the 40 Thieves (Alibabavum 40 Thirudargalum) – (India)',
#   "The Ambassador's Daughter",
#   'Anastasia',
#   'And God Created Woman',
#   'Aparajito (The Unvanquished)',
#   'Around the World in 80 Days',
#   'At Gunpoint',
#   'Attack',
#   'Autumn Leaves',
#   'Away All Boats',
#   'Baby Doll',
#   'Back from Eternity',
#   'Backlash',
#   'The Bad Seed',
#   'Bandido',
#   'The Battle of the River Plate',
#   'Before Sundown (Vor Sonnenuntergang) – (West Germany)',
#   'Behind the Headlines',
#   'The Benny Goodman Story',
#   'The Best Things in Life Are Free',
#   'Between Heaven and Hell',
#   'Beyond a Reasonable Doubt',
#   'Bhowani Junction',
#   'Bigger Than Life',
#   'The Birds and the Bees',
#   'The Black Tent',
#   'Bob le flambeur (Bob the Gambler)',
#   'The Bold and the Brave',
#   'The Boss',
#   'The Bottom of the Bottle',
#   'The Brave One',
#   'The Burmese Harp (Biruma no tategoto)',
#   'The Burning Hills',
#   'Bus Stop',
#   'C.I.D.',
#   'Calabuch (a.k.a. The Rocket from Calabuch)',
#   'Calle Mayor (Main Street)',
#   'Carnival Night (Karnavalnaya noch) – (USSR)',
#   'Carousel',
#   'The Case of the Mukkinese Battle Horn',
#   'The Catered Affair',
#   'Checkpoint (1956 film)',
#   'Child of Sorrow (Anak dalita) – (Philippines)',
#   'Chori Chori',
#   'Comanche',
#   'Come Next Spring',
#   'Congo Crossing',
#   'The Conqueror',
#   'The Court Jester',
#   'Crazed Fruit (Kurutta kajitsu)',
#   'Crime Against Joe',
#   'Crime in the Streets',
#   'A Cry in the Night',
#   'D-Day the Sixth of June',
#   'Dakota Incident',
#   'Dance with Me',
#   'Death in the Garden (La mort en ce jardin)',
#   'Death of a Scoundrel',
#   'Diane',
#   'Donatella',
#   "Don't Look Back",
#   'The Dragon (O Drakos) – (Greece)',
#   'Early Spring (Soshun)',
#   'Earth vs. the Flying Saucers',
#   'The Eddy Duchin Story',
#   'Elena and Her Men',
#   'The Fastest Gun Alive',
#   'The First Texan',
#   'The First Traveling Saleslady',
#   'Forbidden Planet',
#   'Forever',
#   'Friendly Persuasion',
#   'Funtoosh (Funny Man)',
#   'Gaby',
#   'Gervaise',
#   'Giant',
#   "The Girl Can't Help It",
#   'The Girl He Left Behind',
#   'A Girl in Black',
#   'Godzilla',
#   'Good-bye',
#   'Great Day in the Morning',
#   'The Great Locomotive Chase',
#   'The Great Man',
#   'The Green Man',
#   'Gun the Man Down',
#   'Gunslinger',
#   'The Harder They Fall',
#   'The Harvest Month (Elokuu) – (Finland)',
#   'Helen of Troy',
#   'High Society',
#   'Hilda Crane',
#   'Hold Back the Night',
#   'Hollywood or Bust',
#   'Hot Blood',
#   'The Houston Story',
#   'The Hunchback of Notre Dame',
#   'Ich suche Dich (I Seek You)',
#   'The Indian Fighter',
#   'Invasion of the Body Snatchers',
#   'Invitation to the Dance',
#   'It Conquered the World',
#   'Jagte Raho (Stay Awake)',
#   'Johnny Concho',
#   'Jubal',
#   'Julie',
#   'Kanal',
#   'The Killer Is Loose',
#   'The Killers',
#   'The Killing',
#   'The King and Four Queens',
#   'The King and I',
#   'A Kiss Before Dying',
#   'The Last Hunt',
#   'The Last Wagon',
#   'The Leech (Shabab emraa) – (Egypt)',
#   'The Lieutenant Wore Skirts',
#   'Lisbon',
#   'The Lone Ranger',
#   'The Long Arm',
#   'Love Me Tender',
#   'Lust for Life',
#   "A Man Escaped (Un condamné à mort s'est échappé ou Le vent souffle où il veut)",
#   'The Man in the Gray Flannel Suit',
#   'Man on the Tracks (Człowiek na torze) – (Poland)',
#   'The Man Who Knew Too Much',
#   'The Man Who Never Was',
#   'Marie Antoinette Queen of Francem directed by Jean Delannoy',
#   'The Maverick Queen',
#   'Meet Me in Las Vegas',
#   'Merry-Go-Round (Körhinta) – (Hungary)',
#   'Michel Strogoff',
#   'Miracle in the Rain',
#   'Moby Dick',
#   'Mukh O Mukhosh (The Face and the Mask) – (East Pakistan)',
#   'The Mystery of Picasso',
#   'Naked Gun starring Mara Corday and Willard Parker',
#   'Nagareru (Flowing)',
#   'Never Say Goodbye',
#   'New Delhi – (India)',
#   'Old Khottabych (Starik Khottabych) – (U.S.S.R.)',
#   'On the Threshold of Space',
#   'The Opposite Sex',
#   'Othello',
#   'Over-Exposed',
#   'Pardners',
#   'Patterns',
#   'Pillars of the Sky',
#   'Please Murder Me',
#   'Poor but Handsome (Poveri ma belli) – (Italy)',
#   'The Power and the Prize',
#   "Private's Progress",
#   'Professor Hannibal (Hannibál tanár úr)',
#   'The Proud and Profane',
#   'The Proud Ones',
#   'Qivitoq – (Denmark)',
#   'The Rack',
#   'The Railroad Man (Il Ferroviere)',
#   'The Rainmaker',
#   'Raj Hath',
#   'Ransom!',
#   'Reach for the Sky',
#   'The Red Balloon (Le Ballon rouge) – (France)',
#   'The Road of Life (El camino de la vida) – (Mexico)',
#   'Rock Around the Clock',
#   'Rodan',
#   'The Roof (Il Tetto)',
#   'Run for the Sun',
#   'Samurai III: Duel at Ganryu Island',
#   'The Searchers',
#   'Serenade',
#   'Seven Men from Now',
#   'Seven Wonders of the World',
#   'Seven Years in Tibet – (GB)',
#   'The She-Creature',
#   'The Silent World',
#   'Sira` Fi al-Mina (a.k.a. Dark Water)',
#   'Slightly Scarlet',
#   'The Solid Gold Cadillac',
#   'Somebody Up There Likes Me',
#   'The Spanish Gardener',
#   'The Square Jungle',
#   'Star in the Dust',
#   'Stars in Your Eyes – (GB)',
#   'Storm Center',
#   'Street of Shame (Akasen chitai)',
#   'Tea and Sympathy',
#   'The Teahouse of the August Moon',
#   'The Ten Commandments',
#   "There's Always Tomorrow",
#   'Three Brave Men',
#   'Time Table',
#   'Toward the Unknown',
#   'A Town Like Alice',
#   'Trapeze',
#   'Tribute to a Bad Man',
#   'The Twelve Months (Dvenadtsat mesyatsev) – (USSR)',
#   'Uncle Hyacynth (Mi tío Jacinto) – (Spain)',
#   'Valley of Peace (Dolina miru) – (Yugoslavia)',
#   'I Vampiri (The Vampire) – (Italy)',
#   'War and Peace',
#   'Wakeful Eyes',
#   'What a Woman!',
#   'While the City Sleeps',
#   'Who Done It?',
#   "A Woman's Devotion",
#   'Written on the Wind',
#   'The Wrong Man',
#   'X the Unknown',
#   'Yield to the Night',
#   "You Can't Run Away from It",
#   'Zarak'],
#  1947: ['Admiral Nakhimov – (USSR)',
#   'Along the Songhua River (Songhua-jiang shang) – (China)',
#   'Angel and the Badman',
#   'The Bachelor and the Bobby-Soxer',
#   'Between Yesterday and Tomorrow',
#   'The Big Fix',
#   "The Bishop's Wife",
#   'Black Narcissus',
#   'Body and Soul',
#   'Boomerang',
#   'Born to Kill',
#   'The Brasher Doubloon',
#   'Brighton Rock',
#   'Brute Force',
#   'Buck Privates Come Home',
#   'Bury Me Dead',
#   'Captain Boycott',
#   'Captain from Castile',
#   'Carnegie Hall',
#   'Cass Timberlane',
#   'Cinderella (Zolushka) – (U.S.S.R.)',
#   'Copacabana',
#   'Crossfire',
#   'Cynthia (film)',
#   'Daisy Kenyon',
#   'Dancing with Crime',
#   'Dark Passage',
#   'Dead Reckoning',
#   'Deep Valley',
#   'Desert Fury',
#   'Desperate',
#   'Devil in the Flesh (Diable au corps) – (France)',
#   'The Devil Thumbs a Ride',
#   'Dick Tracy Meets Gruesome',
#   'Driftwood',
#   'A Double Life',
#   'Down to Earth',
#   'Dreams That Money Can Buy',
#   'The Egg and I',
#   'Eight Thousand Li of Cloud and Moon (Ba qian li lu yun he yue) – (China)',
#   'Escape Me Never',
#   'The Exile',
#   'Fame is the Spur',
#   'Far Away Love',
#   "The Farmer's Daughter",
#   'Fear in the Night',
#   'Fireworks',
#   'The Flame',
#   'Flesh Will Surrender (Il delitto di Giovanni Episcopo)',
#   'Forever Amber',
#   'The Foxes of Harrow',
#   'Framed',
#   'Frieda',
#   'The Fugitive',
#   'Fun and Fancy Free',
#   'The Garcias Return! (¡Vuelven los Garcia!)',
#   "Gentleman's Agreement",
#   'The Ghost and Mrs. Muir',
#   'Golden Earrings',
#   'Good News',
#   'Green Dolphin Street',
#   'The Guilt of Janet Ames',
#   'The Guilty',
#   'Heaven Only Knows',
#   'Hi-De-Ho',
#   'High Barbaree',
#   'High Wall',
#   'Honeymoon',
#   'The Hucksters',
#   'Hue and Cry',
#   'The Humpbacked Horse (Konyok Gorbunok) – (U.S.S.R.)',
#   'Hungry Hill',
#   'An Ideal Husband',
#   'If Winter Comes',
#   'The Imperfect Lady',
#   'In Those Days (In jenen Tagen) – (Germany)',
#   'It Always Rains on Sunday',
#   'It Happened in Brooklyn',
#   'It Happened on Fifth Avenue',
#   'Jenny and the Soldier (Soldaten og Jenny) – (Denmark)',
#   "Johnny O'Clock",
#   'Killer Dill',
#   'Kiss of Death',
#   'The Lady from Shanghai',
#   'Lady in the Lake',
#   'Last of the Redskins',
#   'The Last Stage (Ostatni etap) – (Poland)',
#   'The Late George Apley',
#   'Law of the Lash',
#   'Life with Father',
#   'A Likely Story',
#   'Living in a Big Way',
#   'The Long Night',
#   'Lost Honeymoon',
#   'The Lost Moment',
#   'Lost Youth (Gioventù perduta)',
#   'Love from a Stranger',
#   'Lured',
#   'The Macomber Affair',
#   'The Man I Love',
#   'The Mark of Cain',
#   'Marriage in the Shadows (Ehe im Schatten) – (East Germany)',
#   'Mine Own Executioner',
#   'Miracle on 34th Street',
#   'Monsieur Verdoux',
#   'Monsieur Vincent',
#   'Moss Rose',
#   'Mother Wore Tights',
#   'Mourning Becomes Electra',
#   'My Favourite Brunette',
#   'My Wild Irish Rose',
#   'Neel Kamal (Blue Lotus)',
#   'Nicholas Nickleby',
#   'Nightmare Alley',
#   'Nora Prentiss',
#   'The October Man',
#   'Odd Man Out',
#   'One Wonderful Sunday (Subarashiki Nichiyōbi)',
#   "L'onorevole Angelina (Parliamentarian Angelina)",
#   'Out of the Blue',
#   'Out of the Past',
#   'The Paradine Case',
#   'The Pearl (La Perla)',
#   'The Perils of Pauline',
#   'Pirates of Monterey',
#   'Possessed',
#   'Pursued',
#   'Quai des Orfèvres',
#   'Railroaded!',
#   'Ramrod',
#   'The Record of a Tenement Gentleman (Nagaya shinshiroku)',
#   'The Red House',
#   'Repeat Performance',
#   'Ride the Pink Horse',
#   'Riffraff',
#   'Road to Rio',
#   'The Romance of Rosy Ridge',
#   'The Root of All Evil',
#   'Roses Are Red',
#   'Scared to Death',
#   "School for Postmen (L'École des facteurs)",
#   'The Sea of Grass',
#   'Secret Agent (Podvig razvedchika)',
#   'The Secret Life of Walter Mitty',
#   'The Senator Was Indiscreet',
#   'A Ship to India (Skepp till India land)',
#   'The Shocking Miss Pilgrim',
#   'Sinbad the Sailor',
#   'Smash-Up',
#   'Snow Trail (Ginrei no hate)',
#   'So Well Remembered',
#   'Something in the Wind',
#   'Song of Scheherazade',
#   'Song of the Thin Man',
#   'The Spring River Flows East (Yi jiang chun shui xiang dong liu) – (China)',
#   'Story of a Bad Woman (Historia de una mala mujer) – (Argentina)',
#   'T-Men',
#   'Temptation Harbour',
#   'They Made Me a Fugitive',
#   "They Won't Believe Me",
#   'This Time for Keeps',
#   'The Three Garcias (Los tres García)',
#   'To Live in Peace (Vivere in pace) – (Italy)',
#   'The Two Mrs. Carrolls',
#   'Trail Street',
#   'Uncle Silas',
#   'Unconquered',
#   'The Unfaithful',
#   'The Unsuspected',
#   'The Voice of the Turtle',
#   'The Web',
#   'Welcome Stranger',
#   'Whispering City',
#   'The Wistful Widow of Wagon Gap',
#   'The Woman on the Beach',
#   'Wyoming'],
#  1948: ['Abbott and Costello Meet Frankenstein',
#   'Act of Violence',
#   'Adventures of Don Juan',
#   'Albuquerque',
#   'The Amazing Mr. X',
#   "L'Amore",
#   'Anna Karenina',
#   'Another Part of the Forest',
#   'April Showers',
#   'Arch of Triumph',
#   "B.F.'s Daughter",
#   'Berlin Express',
#   'The Berliner (Berlin Balade)',
#   'Bicycle Thieves (Ladri di biciclette)',
#   'The Big Clock',
#   'Blanche Fury',
#   'Blonde Ice',
#   'Blood on the Moon',
#   'Bodyguard',
#   'The Boy with Green Hair',
#   'The Bride Goes Wild',
#   'Call Northside 777',
#   'La calle sin sol (The Sunless Street) – (Spain)',
#   'Campus Honeymoon',
#   'Canon City',
#   'Command Decision',
#   'Counterblast',
#   'Cry of the City',
#   'The Dark Past',
#   'A Date with Judy',
#   "Dédée d'Anvers",
#   'Drunken Angel (Yoidore tenshi)',
#   "The Eagle with Two Heads (L'Aigle à deux têtes)",
#   'Easter Parade',
#   'The Emperor Waltz',
#   'Escape',
#   'Eva – (Sweden)',
#   'Every Girl Should Be Married',
#   'The Fallen Idol',
#   'Fighter Squadron',
#   'Force of Evil',
#   'A Foreign Affair',
#   'Fort Apache',
#   'Four Faces West',
#   'Germany Year Zero (Germania anno zero)',
#   'God Reward You (Dios se lo pague)',
#   'Good Sam',
#   'Good-Time Girl',
#   'Green Grass of Wyoming',
#   'The Green Promise',
#   'The Guinea Pig',
#   'Half Past Midnight',
#   'Hamlet',
#   'He Walked by Night',
#   'A Hen in the Wind (Kaze no naka no mendori)',
#   'Hollow Triumph',
#   'Homecoming',
#   'I Remember Mama',
#   'I Walk Alone',
#   'The Iron Curtain',
#   "Isn't It Romantic?",
#   'Joan of Arc',
#   'Johnny Belinda',
#   'Julia Misbehaves starring Greer Garson',
#   'June Bride',
#   'Key Largo',
#   'Kiss the Blood off My Hands',
#   'The Kissing Bandit',
#   'Krakatit',
#   'La Terra Trema',
#   'Ladies of the Chorus',
#   'Lal Dupatta',
#   'The Lame Devil (Le Diable boiteux)',
#   'Letter from an Unknown Woman',
#   'London Belongs to Me',
#   'Louisiana Story',
#   'The Loves of Carmen',
#   'The Luck of the Irish',
#   'Luxury Liner',
#   'Macbeth',
#   'The Mating of Millie',
#   'Mela',
#   'Melody Time',
#   'Mexican Hayride',
#   'Michurin',
#   'Miranda',
#   "Miss Tatlock's Millions",
#   "The Monkey's Paw",
#   'Moonrise',
#   'Morituri – (Germany)',
#   'Mr. Blandings Builds His Dream House',
#   'My Dear Secretary',
#   'Myriad of Lights (Wanjia denghuo) – (China)',
#   'The Mysterious Apartment (Den hemmelighetsfulle leiligheten) – (Norway)',
#   'The Naked City',
#   'Night Has a Thousand Eyes',
#   'No Orchids for Miss Blandish – (GB)',
#   'No Room at the Inn',
#   'Noose',
#   'The Noose Hangs High',
#   'Nosotros los Pobres (We the Poor)',
#   'On an Island with You starring Esther Williams',
#   'One Sunday Afternoon',
#   'One Touch of Venus',
#   'Oliver Twist',
#   'On Our Own Land (Na svoji zemlji) – (Yugoslavia)',
#   'The Paleface',
#   'Les Parents terribles',
#   'The Pirate',
#   'Pitfall',
#   'Port of Call (Hamnstad)',
#   'Portrait of Jennie',
#   'Quartet',
#   'Race Street',
#   'Rachel and the Stranger',
#   'Raw Deal',
#   'Red River',
#   'The Red Shoes',
#   'Relentless',
#   'The Return of October',
#   'Road House',
#   "Rogues' Regiment",
#   'Romance on the High Seas',
#   'Rope',
#   'Ruthless',
#   'Saigon',
#   'The Sainted Sisters',
#   'Saraband for Dead Lovers',
#   'Scott of the Antarctic',
#   'Sealed Verdict',
#   'The Search',
#   'Secret Beyond the Door',
#   'Senza pietà (Without Pity) – (Italy)',
#   'Shaheed',
#   'Silver River',
#   'Sitting Pretty',
#   'Sleep',
#   'Sleeping Car to Trieste',
#   "Smart Girls Don't Talk",
#   'The Snake Pit',
#   'So Evil My Love',
#   'A Song Is Born',
#   'Sorry',
#   'Spring in a Small Town (Xiǎochéng zhī chūn)',
#   'Spring in Park Lane',
#   'State of the Union',
#   'Station West',
#   'The Street with No Name',
#   'Tap Roots',
#   'La Terra Trema (The Earth Will Tremble)',
#   'They Live by Night',
#   'The Three Musketeers',
#   'The Time of Your Life',
#   'Tragic Hunt (Caccia tragica) – (Italy)',
#   'The Treasure of the Sierra Madre',
#   'Treasured Earth (Talpalatnyi föld) – (Hungary)',
#   'Los tres huastecos',
#   'Under the Sun of Rome (Sotto il sole di Roma)',
#   'Unfaithfully Yours',
#   'Up in Central Park',
#   'Ustedes los ricos (you the Rich)',
#   'Vidya',
#   'Waverley Steps – (GB) documentary',
#   'Western Heritage',
#   'When My Baby Smiles at Me',
#   'When You Come Home',
#   'Whiplash',
#   'Whispering Smith',
#   'The Winslow Boy',
#   'Yellow Sky',
#   'You Gotta Stay Happy',
#   'The Young Guard (Molodaya Gvardiya) – (U.S.S.R.)'],
#  1949: ['Abbott and Costello in the Foreign Legion',
#   'The Admiral Was a Lady',
#   'All About Eve',
#   'Ambush',
#   'Annie Get Your Gun',
#   'Armored Car Robbery',
#   'The Asphalt Jungle',
#   'The Astonished Heart',
#   'At War with the Army',
#   "Babul (Father's House)",
#   'Backfire',
#   'The Bandit Queen',
#   'The Baron of Arizona',
#   'Beauty and the Devil (La Beauté du diable)',
#   'Beqasoor',
#   'The Big Lift',
#   'Bitter Springs',
#   'The Black Forest Girl',
#   'The Black Rose',
#   'The Blue Lamp',
#   'Born to Be Bad',
#   'Born Yesterday',
#   'The Breaking Point',
#   'Bright Leaf',
#   'Broken Arrow',
#   'Café Paradis – (Denmark)',
#   'Caged',
#   'Caiçara',
#   'Captain Carey',
#   'Captain China',
#   'Champagne for Caesar',
#   'Cheaper by the Dozen',
#   'Cinderella',
#   'Comanche Territory',
#   'Convicted',
#   'Crisis',
#   'Cyrano de Bergerac',
#   'D.O.A.',
#   'Dallas',
#   "The Damned Don't Cry",
#   'Dance Hall',
#   'Darah dan Doa',
#   'Dark City',
#   "The Daughter of Rosie O'Grady",
#   'Death is a Caress (Døden er et kjærtegn) – (Norway)',
#   'Deported',
#   'Destination Moon',
#   'The Devil Is a Woman (Doña Diabla) – (Mexico)',
#   "Devil's Doorway",
#   'Dial 1119',
#   'Dieu a besoin des hommes (God Needs Man)',
#   'The Eagle and the Hawk',
#   'Edge of Doom',
#   'Les Enfants Terribles',
#   'Escape at Dawn (Akatsuki no dasso) – (Japan)',
#   'The Fall of Berlin (Padeniye Berlina) – (USSR)',
#   'Fancy Pants',
#   'Father Is a Bachelor',
#   'Father of the Bride',
#   'The File on Thelma Jordon',
#   'The Fireball',
#   'The Flame and the Arrow',
#   'The Flowers of St. Francis (Francesco',
#   "For Heaven's Sake",
#   'Frenchie',
#   'The Fuller Brush Girl',
#   'The Furies',
#   'Gabriela',
#   'Gerald McBoing-Boing',
#   'The Glass Menagerie',
#   'Gone to Earth',
#   'Guilty of Treason',
#   'Gun Crazy (aka Deadly is the Female)',
#   'The Gunfighter',
#   'Gunman in the Streets',
#   'The Happiest Days of Your Life',
#   'Harriet Craig',
#   'Harvey',
#   ' The High and the Mighty',
#   'Highly Dangerous',
#   'Highway 301',
#   'The Hollywood Ten',
#   'House by the River',
#   'Hunt the Man Down',
#   'The Iroquois Trail',
#   'I Was a Shoplifter',
#   "I'll Get By",
#   'In a Lonely Place',
#   'The Jackie Robinson Story',
#   'Jogan',
#   'Johnny One-Eye',
#   'Julius Caesar',
#   'Justice is Done (Justice est faite) – (France)',
#   'Key to the City',
#   'The Kid (Xi lu xiang)',
#   'Kill the Umpire',
#   'The Killer That Stalked New York',
#   'Kim',
#   "King Solomon's Mines",
#   'Kiss Tomorrow Goodbye',
#   'A Lady Without Passport',
#   'Last Holiday',
#   'The Lawless',
#   "Let's Dance",
#   'Life (Jeevitham)',
#   'A Life of Her Own',
#   'The Life of Wu Xun (Wu Xun zhuan) – (China)',
#   'Louisa',
#   'Love Happy',
#   'The Magnificent Yankee',
#   'The Man Who Cheated Himself',
#   'The Men',
#   'The Miniver Story',
#   "Mirror of Holland (Spiegel van Holland) – (Netherlands) winner of Short Film Palme d'Or",
#   'Mister 880',
#   'Montana',
#   'Morning Departure (aka Operation Disaster)',
#   "Mrs. O'Malley and Mr. Malone",
#   'The Mudlark',
#   'Mussorgsky – (USSR)',
#   'My Blue Heaven',
#   'My Friend Irma Goes West',
#   'Mystery Street',
#   'Nancy Goes to Rio',
#   'The Nevadan',
#   'Night and the City',
#   'No Man of Her Own',
#   "No Peace Under the Olive Tree (Non c'è pace tra gli ulivi)",
#   'No Way Out',
#   'Odette',
#   'Los Olvidados',
#   'Once a Thief',
#   'One Way Street',
#   'Orphée',
#   'Outrage',
#   'Outside the Wall',
#   'Panic in the Streets',
#   'Path of Hope (Il Cammino della speranza)',
#   'Perfect Strangers',
#   'Please Believe Me',
#   'Post Office Box 1001 (Apartado de correos 1001) – (Spain)',
#   'Prehistoric Women',
#   "Prima comunione (aka Father's Dilemma)",
#   'Quicksand',
#   'Rashomon',
#   'Riding High',
#   'Right Cross',
#   'Rio Grande',
#   'Rocketship X-M',
#   'Rocky Mountain',
#   'Rogues of Sherwood Forest',
#   'La Ronde (The Merry-Go-Round)',
#   'Room to Let',
#   'Scandal (Sukyandaru)',
#   'The Second Face',
#   'The Secret Fury',
#   'September Affair',
#   'Seven Days to Noon',
#   'Shadow on the Wall',
#   'Side Street',
#   'Sierra',
#   'The Sleeping City',
#   'So Long at the Fair',
#   'The Sound of Fury',
#   'Stage Fright',
#   'Stars in My Crown',
#   'State Secret',
#   'Story of a Love Affair (Cronaca di un amore)',
#   'Stromboli',
#   'Summer Stock',
#   "Sunday in August (Domenica d'agosto) – (Italy)",
#   'Sunset Boulevard',
#   'También de Dolor se Canta (They Also Sing from Sadness)',
#   'Tea for Two',
#   'Tension',
#   'This Life of Mine (Wo zhe yi bei zi) – (China)',
#   'Three Came Home',
#   'Three Little Words',
#   'Three Secrets',
#   'A Ticket to Tomahawk',
#   'The Titan: Story of Michelangelo',
#   'To Joy (Till glädje)',
#   'To Please a Lady',
#   'The Toast of New Orleans',
#   'Tomorrow Is Too Late (Domani è troppo tardi)',
#   'The Trap (Past)',
#   'Treasure Island',
#   'Trio',
#   'Tripoli',
#   'Two Flags West',
#   'Two Weeks with Love',
#   'El último caballo (The Last Horse) – (Spain)',
#   'The Underworld Story',
#   'Union Station',
#   'Until We Meet Again (Mata au hi made) – (Japan)',
#   'Variety Lights (Luci del varietà)',
#   'Vendetta',
#   'Virtue for Sale',
#   'Wabash Avenue',
#   'Wagon Master',
#   'Watch the Birdie',
#   'The West Point Story',
#   'When Willie Comes Marching Home',
#   'Where Danger Lives',
#   'Where the Sidewalk Ends',
#   "Winchester '73",
#   'The Woman in Question',
#   'Woman in Hiding',
#   'Woman on the Run',
#   'The Wooden Horse',
#   'The Yellow Cab Man',
#   'The Young and the Damned (Los Olvidados)',
#   'Young Man with a Horn',
#   'Zhukovsky – (USSR)'],
#  1950: ['Abbott and Costello in the Foreign Legion',
#   'The Admiral Was a Lady',
#   'All About Eve',
#   'Ambush',
#   'Annie Get Your Gun',
#   'Armored Car Robbery',
#   'The Asphalt Jungle',
#   'The Astonished Heart',
#   'At War with the Army',
#   "Babul (Father's House)",
#   'Backfire',
#   'The Bandit Queen',
#   'The Baron of Arizona',
#   'Beauty and the Devil (La Beauté du diable)',
#   'Beqasoor',
#   'The Big Lift',
#   'Bitter Springs',
#   'The Black Forest Girl',
#   'The Black Rose',
#   'The Blue Lamp',
#   'Born to Be Bad',
#   'Born Yesterday',
#   'The Breaking Point',
#   'Bright Leaf',
#   'Broken Arrow',
#   'Café Paradis – (Denmark)',
#   'Caged',
#   'Caiçara',
#   'Captain Carey',
#   'Captain China',
#   'Champagne for Caesar',
#   'Cheaper by the Dozen',
#   'Cinderella',
#   'Comanche Territory',
#   'Convicted',
#   'Crisis',
#   'Cyrano de Bergerac',
#   'D.O.A.',
#   'Dallas',
#   "The Damned Don't Cry",
#   'Dance Hall',
#   'Darah dan Doa',
#   'Dark City',
#   "The Daughter of Rosie O'Grady",
#   'Death is a Caress (Døden er et kjærtegn) – (Norway)',
#   'Deported',
#   'Destination Moon',
#   'The Devil Is a Woman (Doña Diabla) – (Mexico)',
#   "Devil's Doorway",
#   'Dial 1119',
#   'Dieu a besoin des hommes (God Needs Man)',
#   'The Eagle and the Hawk',
#   'Edge of Doom',
#   'Les Enfants Terribles',
#   'Escape at Dawn (Akatsuki no dasso) – (Japan)',
#   'The Fall of Berlin (Padeniye Berlina) – (USSR)',
#   'Fancy Pants',
#   'Father Is a Bachelor',
#   'Father of the Bride',
#   'The File on Thelma Jordon',
#   'The Fireball',
#   'The Flame and the Arrow',
#   'The Flowers of St. Francis (Francesco',
#   "For Heaven's Sake",
#   'Frenchie',
#   'The Fuller Brush Girl',
#   'The Furies',
#   'Gabriela',
#   'Gerald McBoing-Boing',
#   'The Glass Menagerie',
#   'Gone to Earth',
#   'Guilty of Treason',
#   'Gun Crazy (aka Deadly is the Female)',
#   'The Gunfighter',
#   'Gunman in the Streets',
#   'The Happiest Days of Your Life',
#   'Harriet Craig',
#   'Harvey',
#   ' The High and the Mighty',
#   'Highly Dangerous',
#   'Highway 301',
#   'The Hollywood Ten',
#   'House by the River',
#   'Hunt the Man Down',
#   'The Iroquois Trail',
#   'I Was a Shoplifter',
#   "I'll Get By",
#   'In a Lonely Place',
#   'The Jackie Robinson Story',
#   'Jogan',
#   'Johnny One-Eye',
#   'Julius Caesar',
#   'Justice is Done (Justice est faite) – (France)',
#   'Key to the City',
#   'The Kid (Xi lu xiang)',
#   'Kill the Umpire',
#   'The Killer That Stalked New York',
#   'Kim',
#   "King Solomon's Mines",
#   'Kiss Tomorrow Goodbye',
#   'A Lady Without Passport',
#   'Last Holiday',
#   'The Lawless',
#   "Let's Dance",
#   'Life (Jeevitham)',
#   'A Life of Her Own',
#   'The Life of Wu Xun (Wu Xun zhuan) – (China)',
#   'Louisa',
#   'Love Happy',
#   'The Magnificent Yankee',
#   'The Man Who Cheated Himself',
#   'The Men',
#   'The Miniver Story',
#   "Mirror of Holland (Spiegel van Holland) – (Netherlands) winner of Short Film Palme d'Or",
#   'Mister 880',
#   'Montana',
#   'Morning Departure (aka Operation Disaster)',
#   "Mrs. O'Malley and Mr. Malone",
#   'The Mudlark',
#   'Mussorgsky – (USSR)',
#   'My Blue Heaven',
#   'My Friend Irma Goes West',
#   'Mystery Street',
#   'Nancy Goes to Rio',
#   'The Nevadan',
#   'Night and the City',
#   'No Man of Her Own',
#   "No Peace Under the Olive Tree (Non c'è pace tra gli ulivi)",
#   'No Way Out',
#   'Odette',
#   'Los Olvidados',
#   'Once a Thief',
#   'One Way Street',
#   'Orphée',
#   'Outrage',
#   'Outside the Wall',
#   'Panic in the Streets',
#   'Path of Hope (Il Cammino della speranza)',
#   'Perfect Strangers',
#   'Please Believe Me',
#   'Post Office Box 1001 (Apartado de correos 1001) – (Spain)',
#   'Prehistoric Women',
#   "Prima comunione (aka Father's Dilemma)",
#   'Quicksand',
#   'Rashomon',
#   'Riding High',
#   'Right Cross',
#   'Rio Grande',
#   'Rocketship X-M',
#   'Rocky Mountain',
#   'Rogues of Sherwood Forest',
#   'La Ronde (The Merry-Go-Round)',
#   'Room to Let',
#   'Scandal (Sukyandaru)',
#   'The Second Face',
#   'The Secret Fury',
#   'September Affair',
#   'Seven Days to Noon',
#   'Shadow on the Wall',
#   'Side Street',
#   'Sierra',
#   'The Sleeping City',
#   'So Long at the Fair',
#   'The Sound of Fury',
#   'Stage Fright',
#   'Stars in My Crown',
#   'State Secret',
#   'Story of a Love Affair (Cronaca di un amore)',
#   'Stromboli',
#   'Summer Stock',
#   "Sunday in August (Domenica d'agosto) – (Italy)",
#   'Sunset Boulevard',
#   'También de Dolor se Canta (They Also Sing from Sadness)',
#   'Tea for Two',
#   'Tension',
#   'This Life of Mine (Wo zhe yi bei zi) – (China)',
#   'Three Came Home',
#   'Three Little Words',
#   'Three Secrets',
#   'A Ticket to Tomahawk',
#   'The Titan: Story of Michelangelo',
#   'To Joy (Till glädje)',
#   'To Please a Lady',
#   'The Toast of New Orleans',
#   'Tomorrow Is Too Late (Domani è troppo tardi)',
# ...
#   'Dune',
#   "Ron's Gone Wrong",
#   'The French Dispatch',
#   'The Harder They Fall',
#   'The Electrical Life of Louis Wain',
#   'Warning',
#   'Passing',
#   'Hypnotic',
#   'Antlers',
#   'Army of Thieves',
#   'A Mouthful of Air',
#   'The Souvenir Part II',
#   'Paranormal Activity: Next of Kin',
#   'The Spine of Night',
#   'Violet',
#   'Heart of Champions',
#   'Eternals',
#   'Red Notice',
#   'Finch',
#   'Spencer',
#   'Dangerous',
#   'Love Hard',
#   'The Beta Test',
#   'Clifford the Big Red Dog',
#   'Tick, Tick... Boom!',
#   'Home Sweet Home Alone',
#   'Apex',
#   'The Power of the Dog',
#   'Bruised',
#   'The Princess Switch 3: Romancing the Star',
#   'Ghostbusters: Afterlife',
#   'King Richard',
#   'Extinct',
#   "C'mon C'mon",
#   'Black Friday',
#   'Zeros and Ones',
#   'Friend of the World',
#   'Encanto',
#   'House of Gucci',
#   'The Unforgivable',
#   'Resident Evil: Welcome to Raccoon City',
#   '8-Bit Christmas',
#   'The Humans',
#   'South Park: Post Covid',
#   'Licorice Pizza',
#   'Single All the Way',
#   'Back to the Outback',
#   'Diary of a Wimpy Kid',
#   'Encounter',
#   'Mixtape',
#   'Deadlock',
#   'West Side Story',
#   "Don't Look Up",
#   'National Champions',
#   'Being the Ricardos',
#   'Red Rocket',
#   'The Hating Game',
#   'Rumble',
#   'South Park: Post Covid: The Return of Covid',
#   'Spider-Man: No Way Home',
#   'Nightmare Alley',
#   'The Lost Daughter',
#   'Swan Song',
#   'The Tender Bar',
#   'Mother/Android',
#   'Fortress',
#   'Sing 2',
#   'The Matrix Resurrections',
#   "The King's Man",
#   'The Tragedy of Macbeth',
#   'A Journal for Jordan',
#   'American Underdog',
#   'Memoria',
#   nan],
#  2022: ['Top Gun: Maverick',
#   'Avatar: The Way of Water',
#   'Black Panther: Wakanda Forever',
#   'Doctor Strange in the Multiverse of Madness',
#   'Jurassic World Dominion',
#   'Minions: The Rise of Gru',
#   'The Batman',
#   'Thor: Love and Thunder',
#   'Sonic the Hedgehog 2',
#   'Puss in Boots: The Last Wish',
#   'The 355',
#   'The Legend of La Llorona',
#   'The Commando',
#   'American Siege',
#   'Scream',
#   'Hotel Transylvania: Transformania',
#   'Shattered',
#   'The Royal Treatment',
#   'Redeeming Love',
#   "The King's Daughter",
#   'The Tiger Rising',
#   'Hellblazers',
#   'The Fallout',
#   'Home Team',
#   'The Ice Age Adventures of Buck Wild',
#   'Clean',
#   'Jackass Forever',
#   'Moonfall',
#   'Last Looks',
#   'The Long Night',
#   'Kimi',
#   'Shut In',
#   'Death on the Nile',
#   'Marry Me',
#   'Blacklight',
#   'I Want You Back',
#   'Tall Girl 2',
#   'The Sky Is Everywhere',
#   'The In Between',
#   'Fistful of Vengeance',
#   'Uncharted',
#   'Dog',
#   'Texas Chainsaw Massacre',
#   'The Cursed',
#   'A Fairy Tale After All',
#   'Cyrano',
#   'Studio 666',
#   'A Madea Homecoming',
#   'No Exit',
#   "I'll Find You",
#   'Gasoline Alley',
#   'The Batman',
#   'After Yang',
#   'Fresh',
#   'A Day to Die',
#   'The Hyperions',
#   'The Adam Project',
#   'Turning Red',
#   "Tyson's Run",
#   'Rescued by Ruby',
#   'The Outfit',
#   'Deep Water',
#   'Cheaper by the Dozen',
#   'Windfall',
#   'X',
#   'Umma',
#   'Alice',
#   'Master',
#   'Measure of Revenge',
#   'The Lost City',
#   'Everything Everywhere All at Once',
#   'Infinite Storm',
#   '7 Days',
#   'Moonshot',
#   'Morbius',
#   'The Bubble',
#   'The Contractor',
#   'Better Nate Than Ever',
#   'Apollo 10 1⁄2: A Space Age Childhood',
#   'Sonic the Hedgehog 2',
#   'Ambulance',
#   'All the Old Knives',
#   'Metal Lords',
#   'Father Stu',
#   'Fantastic Beasts: The Secrets of Dumbledore',
#   'Dual',
#   'Titanic 666',
#   'The Bad Guys',
#   'The Northman',
#   'The Unbearable Weight of Massive Talent',
#   'Polar Bear',
#   'The Survivor',
#   'Memory',
#   'Crush',
#   "Fortress: Sniper's Eye",
#   'Corrective Measures',
#   'Doctor Strange in the Multiverse of Madness',
#   'Along for the Ride',
#   'Marmaduke',
#   'Escape the Field',
#   'Operation Mincemeat',
#   'Senior Year',
#   'Firestarter',
#   'Sneakerella',
#   'On the Count of Three',
#   'Private Property',
#   'Family Camp',
#   'Montana Story',
#   'Vendetta',
#   'Downton Abbey: A New Era',
#   "Chip 'n Dale: Rescue Rangers",
#   'Good Mourning',
#   'The Valet',
#   'Emergency',
#   'Top Gun: Maverick',
#   "The Bob's Burgers Movie",
#   'Zero Contact',
#   'A Chiara',
#   'South Park The Streaming Wars',
#   'Hollywood Stargirl',
#   'Benediction',
#   'Interceptor',
#   'Fire Island',
#   'Watcher',
#   'Dashcam',
#   'White Elephant',
#   'Hustle',
#   'Jurassic World Dominion',
#   'Jennifer Lopez: Halftime',
#   'Father of the Bride',
#   'Lightyear',
#   'Spiderhead',
#   'Jerry & Marge Go Large',
#   'Cha Cha Real Smooth',
#   'Mid-Century',
#   'Abandoned',
#   'Beavis and Butt-Head Do the Universe',
#   'Elvis',
#   'The Black Phone',
#   'The Man from Toronto',
#   'The Sea Beast',
#   'Marcel the Shell with Shoes On',
#   'Rise',
#   'Press Play',
#   'Beauty',
#   'Minions: The Rise of Gru',
#   'The Forgiven',
#   "Mr. Malcolm's List",
#   'The Princess',
#   'Hot Seat',
#   'Hello, Goodbye, and Everything in Between',
#   'Thor: Love and Thunder',
#   'South Park The Streaming Wars Part 2',
#   'The Gray Man',
#   'Where the Crawdads Sing',
#   'Paws of Fury: The Legend of Hank',
#   'Persuasion',
#   'Gone in the Night',
#   '1Up',
#   'Wrong Place',
#   "Don't Make Me Go",
#   "He's Watching",
#   'Nope',
#   "Anything's Possible",
#   'Alone Together',
#   'DC League of Super-Pets',
#   'Thirteen Lives',
#   'Vengeance',
#   'Sharp Stick',
#   'Not Okay',
#   'Paradise Highway',
#   'Resurrection',
#   'A Love Song',
#   'Honor Society',
#   'Allegoria',
#   'Kung Fu Ghost',
#   'Bullet Train',
#   'Easter Sunday',
#   'Rise of the Teenage Mutant Ninja Turtles: The Movie',
#   'Luck',
#   'Prey',
#   'Bodies Bodies Bodies',
#   'They/Them',
#   'Secret Headquarters',
#   'Day Shift',
#   'Mack & Rita',
#   'Fall',
#   'Emily the Criminal',
#   'Summering',
#   'Beast',
#   'Orphan: First Kill',
#   'Spin Me Round',
#   "Delia's Gone",
#   'Three Thousand Years of Longing',
#   'Samaritan',
#   'Me Time',
#   'The Invitation',
#   'Breaking',
#   'Funny Pages',
#   'Honk for Jesus. Save Your Soul.',
#   'Gigi & Nate',
#   'Wire Room',
#   'One Way',
#   'After Ever Happy',
#   'Pinocchio',
#   'Barbarian',
#   'End of the Road',
#   'Lifemark',
#   'Clerks III',
#   'The Woman King',
#   'See How They Run',
#   'Blonde',
#   'Pearl',
#   'Do Revenge',
#   'The Silent Twins',
#   'Confess, Fletch',
#   'Moonage Daydream',
#   "God's Country",
#   'Goodnight Mommy',
#   'Running the Bases',
#   'Jeepers Creepers: Reborn',
#   "Don't Worry Darling",
#   'Catherine Called Birdy',
#   'Section Eight',
#   'Lou',
#   'On the Come Up',
#   "A Jazzman's Blues",
#   'The Munsters',
#   'Smile',
#   'Bros',
#   'Hocus Pocus 2',
#   'The Greatest Beer Run Ever',
#   'The Good House',
#   'Luckiest Girl Alive',
#   'Dead for a Dollar',
#   "My Best Friend's Exorcism",
#   "Mr. Harrigan's Phone",
#   'Terrifier 2',
#   'Lyle, Lyle, Crocodile',
#   'Amsterdam',
#   'Tár',
#   'Hellraiser',
#   'Significant Other',
#   'Grimcutty',
#   'Halloween Ends',
#   'Till',
#   'Rosaline',
#   'Raymond & Ray',
#   'The Curse of Bridge Hollow',
#   'Bitch Ass',
#   'The School for Good and Evil',
#   'The Good Nurse',
#   'V/H/S/99',
#   'Black Adam',
#   'Ticket to Paradise',
#   'Wendell & Wild',
#   'The Banshees of Inisherin',
#   'My Policeman',
#   'Aftersun',
#   'Detective Knight: Rogue',
#   'The Return of Tanya Tucker: Featuring Brandi Carlile',
#   'Armageddon Time',
#   'Call Jane',
#   'Causeway',
#   'Prey for the Devil',
#   'Run Sweetheart Run',
#   'The Wonder',
#   'The Independent',
#   'Enola Holmes 2',
#   "My Father's Dragon",
#   'Weird: The Al Yankovic Story',
#   'The Estate',
#   'The Minute You Wake Up Dead',
#   'Dear Zoe',
#   'Something in the Dirt',
#   'Good Night Oppy',
#   "Guillermo del Toro's Pinocchio",
#   'Falling for Christmas',
#   'Black Panther: Wakanda Forever',
#   'The Fabelmans',
#   'Spirited',
#   'Is That Black Enough for You?!?',
#   'Paradise City',
#   'Poker Face',
#   'A Christmas Story Christmas',
#   'She Said',
#   'The Menu',
#   'Disenchanted',
#   'Slumberland',
#   'Bones and All',
#   'The Inspection',
#   'Scrooge: A Christmas Carol',
#   'Lamborghini: The Man Behind the Legend',
#   'The People We Hate at the Wedding',
#   'Strange World',
#   'Glass Onion: A Knives Out Mystery',
#   'Devotion',
#   'Nanny',
#   'The Noel Diary',
#   'White Noise',
#   'Violent Night',
#   'Emancipation',
#   'Spoiler Alert',
#   'Diary of a Wimpy Kid: Rodrick Rules',
#   'Darby and the Dead',
#   "Lady Chatterley's Lover",
#   'The Eternal Daughter',
#   'Almighty Zeus',
#   "Roald Dahl's Matilda the Musical",
#   'Empire of Light',
#   'Night at the Museum: Kahmunrah Rises Again',
#   'The Whale',
#   "Something from Tiffany's",
#   'Detective Knight: Redemption',
#   'The Mean One',
#   'Avatar: The Way of Water',
#   'Puss in Boots: The Last Wish',
#   'Babylon',
#   'Whitney Houston: I Wanna Dance with Somebody',
#   'The Pale Blue Eye',
#   'Women Talking',
#   'A Man Called Otto',
#   'Alice, Darling',
#   nan,
#   nan,
#   nan,
#   nan],
#  2023: ['Barbie',
#   'The Super Mario Bros. Movie',
#   'Spider-Man: Across the Spider-Verse',
#   'Guardians of the Galaxy Vol. 3',
#   'Oppenheimer †',
#   'The Little Mermaid',
#   'Wonka †',
#   'Ant-Man and the Wasp: Quantumania',
#   'John Wick: Chapter 4',
#   'Sound of Freedom',
#   'M3GAN',
#   'The Old Way',
#   'The Devil Conspiracy',
#   'Plane',
#   'House Party',
#   'Sick',
#   'The Drop',
#   'Dog Gone',
#   "There's Something Wrong with the Children",
#   'Missing',
#   'The Son',
#   'When You Finish Saving the World',
#   'Detective Knight: Independence',
#   'Kids vs. Aliens',
#   'Teen Wolf: The Movie',
#   'You People',
#   'Shotgun Wedding',
#   'Maybe I Do',
#   'Life Upside Down',
#   'Fear',
#   'Knock at the Cabin',
#   '80 for Brady',
#   'The Locksmith',
#   'Baby Ruby',
#   "Freedom's Path",
#   'The Wedding Hustler',
#   "Magic Mike's Last Dance",
#   'Sharper',
#   'Your Place or Mine',
#   'Somebody I Used to Know',
#   'Consecration',
#   'The Outwaters',
#   'Ant-Man and the Wasp: Quantumania',
#   'Cocaine Bear',
#   'We Have a Ghost',
#   'Luther: The Fallen Sun',
#   'Jesus Revolution',
#   'Bruiser',
#   'Linoleum',
#   "God's Time",
#   'Creed III',
#   'Operation Fortune: Ruse de Guerre',
#   'A Little White Lie',
#   'Children of the Corn',
#   'Palm Trees and Power Lines',
#   'The Year Between',
#   'Unseen',
#   'Craving',
#   'Scream VI',
#   '65',
#   'Champions',
#   'Chang Can Dunk',
#   'Southern Gospel',
#   'Shazam! Fury of the Gods',
#   'Boston Strangler',
#   "The Magician's Elephant",
#   'Moving On',
#   'Wildflower',
#   'Supercell',
#   'Pinball: The Man Who Saved the Game',
#   'John Wick: Chapter 4',
#   'A Good Person',
#   'The Tutor',
#   'Last Sentinel',
#   'Adalynn',
#   'Dungeons & Dragons: Honor Among Thieves',
#   'Murder Mystery 2',
#   'Tetris',
#   'Spinning Gold',
#   'Space Oddity',
#   'A Thousand and One',
#   'Assassin',
#   'Acidman',
#   'Malum',
#   'Miracle at Manchester',
#   'The Super Mario Bros. Movie',
#   'Air',
#   'Praise This',
#   'Showing Up',
#   'Paint',
#   'On a Wing and a Prayer',
#   'Chupa',
#   'How to Blow Up a Pipeline',
#   'One True Loves',
#   'Beautiful Disaster',
#   'Renfield',
#   'Beau Is Afraid',
#   "The Pope's Exorcist",
#   'Mafia Mamma',
#   'Sweetwater',
#   'Nefarious',
#   'Rare Objects',
#   'Quasi',
#   'Evil Dead Rise',
#   "Guy Ritchie's The Covenant",
#   'Ghosted',
#   'Chevalier',
#   'Somewhere in Queens',
#   'Carmen',
#   "A Tourist's Guide to Love",
#   'The Artifice Girl',
#   'Peter Pan & Wendy',
#   "Are You There God? It's Me, Margaret.",
#   'Big George Foreman',
#   'Sisu',
#   'Clock',
#   'Guardians of the Galaxy Vol. 3',
#   'Love Again',
#   'Book Club: The Next Chapter',
#   'The Mother',
#   "Fool's Paradise",
#   'Hypnotic',
#   'Crater',
#   'Knights of the Zodiac',
#   'Mercy',
#   'Monica',
#   'The Starling Girl',
#   'Rally Road Racers',
#   'Fast X',
#   "White Men Can't Jump",
#   'Master Gardener',
#   'Sanctuary',
#   'Robots',
#   'Moon Garden',
#   'The Little Mermaid',
#   'About My Father',
#   'Kandahar',
#   'The Machine',
#   'You Hurt My Feelings',
#   'The Wrath of Becky',
#   'Reality',
#   'Spider-Man: Across the Spider-Verse',
#   'The Boogeyman',
#   'Past Lives',
#   'Shooting Stars',
#   'Transformers: Rise of the Beasts',
#   "Flamin' Hot",
#   'Dalíland',
#   'Jagged Mind',
#   'The Flash',
#   'Elemental',
#   'Asteroid City',
#   'Extraction 2',
#   'The Blackening',
#   'Surrounded',
#   'No Hard Feelings',
#   'The Perfect Find',
#   "World's Best",
#   'God Is a Bullet',
#   'Wonderwell',
#   'Indiana Jones and the Dial of Destiny',
#   'Ruby Gillman, Teenage Kraken',
#   'Nimona',
#   'Confidential Informant',
#   "Prisoner's Daughter",
#   'The Unseen',
#   'Sound of Freedom',
#   'Insidious: The Red Door',
#   'Joy Ride',
#   'The Out-Laws',
#   'Earth Mama',
#   'Biosphere',
#   'Mission: Impossible – Dead Reckoning Part One',
#   'They Cloned Tyrone',
#   'Theater Camp',
#   'Barbie',
#   'Oppenheimer',
#   'Cobweb',
#   'The Beanie Bubble',
#   'Zoey 102',
#   'Haunted Mansion',
#   'Sympathy for the Devil',
#   'Circus Maximus',
#   'Happiness for Beginners',
#   'War Pony',
#   'The Unknown Country',
#   'Blue Hour: The Disappearance of Nick Brandreth',
#   'Teenage Mutant Ninja Turtles: Mutant Mayhem',
#   'Mike & Fred vs The Dead',
#   'Meg 2: The Trench',
#   'Shortcomings',
#   "Dreamin' Wild",
#   'Corner Office',
#   'What Comes Around',
#   'The Passenger',
#   'The Last Voyage of the Demeter',
#   'Heart of Stone',
#   'Red, White & Royal Blue',
#   'Jules',
#   'Inside Man',
#   'Blue Beetle',
#   'Strays',
#   'The Monkey King',
#   'Landscape with Invisible Hand',
#   'Back on the Strip',
#   'The Adults',
#   'Gran Turismo',
#   'Retribution',
#   'Vacation Friends 2',
#   'You Are So Not Invited to My Bat Mitzvah',
#   'Bottoms',
#   'Golda',
#   'The Hill',
#   'The Equalizer 3',
#   'The Good Mother',
#   'All Fun and Games',
#   'Yoshiki: Under the Sky',
#   'The Nun II',
#   'My Big Fat Greek Wedding 3',
#   'Sitting in Bars with Cake',
#   'Aristotle and Dante Discover the Secrets of the Universe',
#   'After Everything',
#   'A Haunting in Venice',
#   'Dumb Money',
#   'Love at First Sight',
#   'A Million Miles Away',
#   'The Retirement Plan',
#   'Outlaw Johnny Black',
#   'Camp Hideout',
#   'The Inventor',
#   'Expend4bles',
#   'Spy Kids: Armageddon',
#   'Reptile',
#   'Cassandro',
#   'Flora and Son',
#   'No One Will Save You',
#   'It Lives Inside',
#   'Everybody Dies by the End',
#   'The Kill Room',
#   'The Creator',
#   'Saw X',
#   'Fair Play',
#   'Heist 88',
#   'The Re-Education of Molly Singer',
#   'Deliver Us',
#   'Oracle',
#   'Appendage',
#   'The Exorcist: Believer',
#   'Pet Sematary: Bloodlines',
#   'Totally Killer',
#   'V/H/S/85',
#   'The Caine Mutiny Court-Martial',
#   'Dicks: The Musical',
#   'Foe',
#   'She Came to Me',
#   'The Burial',
#   'Desperation Road',
#   "Miranda's Victim",
#   'Cat Person',
#   'The Mill',
#   'Down Low',
#   'Dark Harvest',
#   'Taylor Swift: The Eras Tour',
#   'Dear David',
#   'Divinity',
#   'In the Fire',
#   'Killers of the Flower Moon',
#   'Pain Hustlers',
#   'Nyad',
#   'Old Dads',
#   "Butcher's Crossing",
#   'The Other Zoey',
#   'Sick Girl',
#   'The Persian Version',
#   "Five Nights at Freddy's",
#   'Freelance',
#   'The Killer',
#   'Under the Boardwalk',
#   'Priscilla',
#   'The Holdovers',
#   'Fingernails',
#   'Suitable Flesh',
#   'Sight',
#   'Hell House LLC Origins: The Carmichael Manor',
#   'What Happened at 625 River Road',
#   'Quiz Lady',
#   'Rustin',
#   "The Marsh King's Daughter",
#   'What Happens Later',
#   'All Dirt Roads Taste of Salt',
#   "Helen's Dead",
#   'At the Gates',
#   'Rumble Through the Dark',
#   'The Marvels',
#   'Dream Scenario',
#   'Journey to Bethlehem',
#   'Your Lucky Day',
#   "It's a Wonderful Knife",
#   'Manodrome',
#   'The Master Chief: Part One',
#   'Best. Christmas. Ever!',
#   'The Hunger Games: The Ballad of Songbirds & Snakes',
#   'Trolls Band Together',
#   'Thanksgiving',
#   'Next Goal Wins',
#   'Saltburn',
#   'May December',
#   'Dashing Through the Snow',
#   "Please Don't Destroy: The Treasure of Foggy Mountain",
#   'Leo',
#   'Wish',
#   'Napoleon',
#   'Maestro',
#   'Leave the World Behind',
#   'Good Burger 2',
#   'Genie',
#   'Family Switch',
#   'Renaissance: A Film by Beyoncé',
#   'Silent Night',
#   'Candy Cane Lane',
#   'Eileen',
#   'The Shift',
#   'Holiday Twist',
#   'Abigail',
#   'Waitress: The Musical',
#   'Poor Things',
#   'Origin',
#   'Diary of a Wimpy Kid Christmas: Cabin Fever',
#   'Our Son',
#   'The Cello',
#   'The Oath',
#   'Craig Before the Creek',
#   'Wonka',
#   'Chicken Run: Dawn of the Nugget',
#   'Rebel Moon',
#   'American Fiction',
#   'The Family Plan',
#   'Finestkind',
#   'The Zone of Interest',
#   'City of Love',
#   'Aquaman and the Lost Kingdom',
#   'Migration',
#   'Anyone but You',
#   'The Iron Claw',
#   "Freud's Last Session",
#   'Memory',
#   'The Color Purple',
#   'The Boys in the Boat',
#   'Ferrari',
#   'Good Grief']}

# %%
df_dict = {}
df_dict["Title"] = []
df_dict["Year"] = []
df_dict["Content"] = []

for year, titles in title_dict.items():
    
    display.clear_output(wait=True)
    display.display(f"Year: {year}")
    
    for title in titles: 
        
        # remove film that has no wiki page
        film = None
        try:
            film = wikipedia.page(title)
        except: 
            continue; 
            
        df_dict["Title"].append(title)
        df_dict["Year"].append(year)
        df_dict["Content"].append(film.summary)
# Out:
# 'Year: 2023'

# %%
pd.DataFrame.from_dict(df_dict)
# Out:
#                             Title  Year  \
# 0         Abe Lincoln in Illinois  1940
# 1         All This and Heaven Too  1940
# 2      Andy Hardy Meets Debutante  1940
# 3            Angels Over Broadway  1940
# 4           Anne of Windy Poplars  1940
# ...                           ...   ...
# 12263               The Iron Claw  2023
# 12264                      Memory  2023
# 12265        The Boys in the Boat  2023
# 12266                     Ferrari  2023
# 12267                  Good Grief  2023
#
#                                                  Content
# 0      Abe Lincoln in Illinois is a 1940 biographical...
# 1      All This, and Heaven Too is a 1940 American dr...
# 2      Andy Hardy Meets Debutante is a 1940 American ...
# 3      Angels Over Broadway (also called Before I Die...
# 4      Anne of Windy Poplars—published as Anne of Win...
# ...                                                  ...
# 12263  The Iron Claw is a 2023 biographical sports dr...
# 12264  Memory is the faculty of the mind by which dat...
# 12265  The Boys in the Boat: Nine Americans and Their...
# 12266  Ferrari S.p.A. (; Italian: [ferˈraːri]) is an ...
# 12267  Good Grief is a 2023 American comedy-drama fil...
#
# [12268 rows x 3 columns]

# %%
df = pd.DataFrame.from_dict(df_dict)

# %%
df.to_csv('movies.csv', index=False)
